# %% [markdown]
# <a href="https://colab.research.google.com/github/HauThierry/HauThierry/blob/main/Untitled30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=P6kSc3qVph0&list=PLO_fdPEVlfKoHQ3Ua2NtDL4nmynQC8YiS
# PYTHON SKLEARN: KNN, LinearRegressio

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(0)
m = 100 # creation de 100 échantillons
X = np.linspace(0, 10, m).reshape(m,1)
y = X + np.random.randn(m, 1)

plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X, y) # entrainement du modele
model.score(X, y) # évaluation avec le coefficient de corrélation
# Out:
# 0.8881140743377214

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X), c='red')
