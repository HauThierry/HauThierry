# %% [markdown]
# <a href="https://colab.research.google.com/github/HauThierry/HauThierry/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression # Added this import
data = pd.read_csv("dataset.csv")
data.head()
X = data.drop("label", axis=1)
Y = data["label"]

X_train, X_test, Y_train, Y_test = train_test_split(    X, Y, test_size=0.3, random_state=42)
model = LogisticRegression()
model.fit(X_train, Y_train) # Corrected variable names
Y_pred = model.predict(X_test) # Corrected variable names
print(classification_report(Y_test, Y_pred)) # Corrected variable names
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3314587402.py in <cell line: 0>()
#       6 from sklearn.metrics import classification_report, confusion_matrix
#       7 from sklearn.linear_model import LogisticRegression # Added this import
# ----> 8 data = pd.read_csv("dataset.csv")
#       9 data.head()
#      10 X = data.drop("label", axis=1)
#
# ...
